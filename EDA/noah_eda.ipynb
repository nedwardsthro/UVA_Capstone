# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# root = "/content/drive/Shared  M/Capstone - Albemarle County Public Schools/Data/"
# sample_data_path = os.path.join(., "Reading_Dataset_UVA_Deidentified_01-30-24.xlsx")

# math_df = pd.read_excel(sample_data_path, "Math 6-8")
read_df = pd.read_excel("/content/drive/MyDrive/Capstone - Albemarle County Public Schools/Data/Reading_Dataset_UVA_Deidentified_01-30-24.xlsx", "Reading_Dataset")

# %%
pd.options.display.max_columns = None

# %%
read_df.head(n=5)
# Out:
#   Generated Unique ID      Race Gender English Learner  \
# 0            08FA686D  Hispanic   Male             Yes
# 1            88604A2F  Hispanic   Male             Yes
# 2            BA232D41  Hispanic   Male             Yes
# 3            BC8BD3FF     Other   Male             Yes
# 4            043966CE  Hispanic   Male             Yes
#
#   Students with Disabilities      Grade               Test Name   \
# 0                         No  8th Grade  Gr 8 Reading (2017) CAT
# 1                         No  8th Grade  Gr 8 Reading (2017) CAT
# 2                         No  8th Grade  Gr 8 Reading (2017) CAT
# 3                         No  8th Grade  Gr 8 Reading (2017) CAT
# 4                         No  8th Grade  Gr 8 Reading (2017) CAT
#
#         Teacher License Type  Teacher Years Experience Teacher Highest Degree  \
# 0  Postgraduate Professional                      23.0              Doctorate
# 1  Postgraduate Professional                      23.0              Doctorate
# 2  Postgraduate Professional                      23.0              Doctorate
# 3  Postgraduate Professional                      23.0              Doctorate
# 4  Postgraduate Professional                      23.0              Doctorate
#
#    Teacher Birth Year Teacher Gender Teacher Race/Ethnicity  \
# 0              1966.0         Female                  White
# 1              1966.0         Female                  White
# 2              1966.0         Female                  White
# 3              1966.0         Female                  White
# 4              1966.0         Female                  White
#
#   Certified Principal Type of Principal Certification Certified Teacher  \
# 0                   Y                            FULL                 Y
# 1                   Y                            FULL                 Y
# 2                   Y                            FULL                 Y
# 3                   Y                            FULL                 Y
# 4                   Y                            FULL                 Y
#
#   Type of Teacher Certification  Year of Teacher Certification  \
# 0                         MICRO                         2019.0
# 1                         MICRO                         2019.0
# 2                         MICRO                         2019.0
# 3                         MICRO                         2019.0
# 4                         MICRO                         2019.0
#
#    Value Added Score  Expected Achievement  Actual Achievement  \
# 0           1.423380            302.576620                 304
# 1         -39.919437            330.919437                 291
# 2           5.593113            317.406887                 323
# 3         -10.130028            317.130028                 307
# 4         -78.686297            321.686297                 243
#
#    Vertical Scaled Score   Actual Achievement Percentile
# 0                    1444                              3
# 1                    1420                              2
# 2                    1464                              6
# 3                    1434                              4
# 4                    1279                              1

# %%
read_df[['Teacher Race/Ethnicity', 'Race']].value_counts().reset_index().sort_values('Teacher Race/Ethnicity')
# Out:
#                         Teacher Race/Ethnicity                           Race  \
# 19                                       Asian  Black, not of Hispanic origin
# 17                                       Asian                          Other
# 16                                       Asian  White, not of Hispanic origin
# 18                                       Asian                       Hispanic
# 14                   Black or African American                          Other
# 7                    Black or African American                       Hispanic
# 9                    Black or African American  Black, not of Hispanic origin
# 6                    Black or African American  White, not of Hispanic origin
# 5                           Hispanic or Latino  White, not of Hispanic origin
# 8                           Hispanic or Latino                       Hispanic
# 13                          Hispanic or Latino                          Other
# 15                          Hispanic or Latino  Black, not of Hispanic origin
# 4   Two or more races (Not Hispanic or Latino)  White, not of Hispanic origin
# 10  Two or more races (Not Hispanic or Latino)                       Hispanic
# 11  Two or more races (Not Hispanic or Latino)                          Other
# 12  Two or more races (Not Hispanic or Latino)  Black, not of Hispanic origin
# 3                                        White  Black, not of Hispanic origin
# 2                                        White                          Other
# 1                                        White                       Hispanic
# 0                                        White  White, not of Hispanic origin
#
#        0
# 19     2
# 17     4
# 16    10
# 18     3
# 14    20
# 7     48
# 9     30
# 6     54
# 5     65
# 8     43
# 13    20
# 15    15
# 4    104
# 10    25
# 11    25
# 12    22
# 3    471
# 2    551
# 1    626
# 0   2597

# %%
read_df.groupby('Race').mean()
# Out:
# <ipython-input-48-3238915fec8a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   read_df.groupby('Race').mean()
#                                Teacher Years Experience  Teacher Birth Year  \
# Race
# Black, not of Hispanic origin                  9.764815         1984.592593
# Hispanic                                      10.798658         1982.620134
# Other                                         10.874194         1983.000000
# White, not of Hispanic origin                 11.528269         1981.675618
#
#                                Year of Teacher Certification  \
# Race
# Black, not of Hispanic origin                    2021.817518
# Hispanic                                         2021.272727
# Other                                            2021.739362
# White, not of Hispanic origin                    2021.384449
#
#                                Value Added Score  Expected Achievement  \
# Race
# Black, not of Hispanic origin           5.102722            388.661522
# Hispanic                                3.568829            389.288101
# Other                                   7.336266            440.929557
# White, not of Hispanic origin           9.327297            449.222780
#
#                                Actual Achievement  Vertical Scaled Score   \
# Race
# Black, not of Hispanic origin          394.591150             1545.690265
# Hispanic                               391.458607             1541.082786
# Other                                  443.693523             1642.052133
# White, not of Hispanic origin          457.579521             1673.341309
#
#                                Actual Achievement Percentile
# Race
# Black, not of Hispanic origin                      35.240708
# Hispanic                                           34.608410
# Other                                              57.826224
# White, not of Hispanic origin                      63.877551

# %%
read_df[['Race', 'Gender', 'English Learner', 'Students with Disabilities']].value_counts().reset_index().rename(columns = {0:'Count'})
# Out:
#                              Race  Gender English Learner  \
# 0   White, not of Hispanic origin    Male              No
# 1   White, not of Hispanic origin  Female              No
# 2                           Other    Male              No
# 3   Black, not of Hispanic origin  Female              No
# 4                           Other  Female              No
# 5                        Hispanic  Female              No
# 6   White, not of Hispanic origin    Male              No
# 7   Black, not of Hispanic origin    Male              No
# 8                        Hispanic    Male              No
# 9                        Hispanic    Male             Yes
# 10                       Hispanic  Female             Yes
# 11  White, not of Hispanic origin  Female              No
# 12  Black, not of Hispanic origin    Male              No
# 13  Black, not of Hispanic origin  Female              No
# 14                          Other    Male             Yes
# 15                       Hispanic    Male             Yes
# 16                          Other  Female             Yes
# 17                          Other    Male              No
# 18                       Hispanic    Male              No
# 19                          Other  Female              No
# 20  White, not of Hispanic origin  Female             Yes
# 21  White, not of Hispanic origin    Male             Yes
# 22                       Hispanic  Female             Yes
# 23                       Hispanic  Female              No
# 24  Black, not of Hispanic origin    Male             Yes
# 25                          Other  Female             Yes
# 26  Black, not of Hispanic origin  Female             Yes
# 27                          Other    Male             Yes
# 28  White, not of Hispanic origin    Male             Yes
#
#    Students with Disabilities  Count
# 0                          No   1261
# 1                          No   1233
# 2                          No    258
# 3                          No    248
# 4                          No    243
# 5                          No    241
# 6                         Yes    207
# 7                          No    206
# 8                          No    170
# 9                          No    139
# 10                         No    131
# 11                        Yes    113
# 12                        Yes     58
# 13                        Yes     42
# 14                         No     40
# 15                        Yes     30
# 16                         No     30
# 17                        Yes     30
# 18                        Yes     26
# 19                        Yes     24
# 20                         No     14
# 21                         No     13
# 22                        Yes     13
# 23                        Yes     11
# 24                         No      9
# 25                        Yes      6
# 26                         No      2
# 27                        Yes      2
# 28                        Yes      1

# %%
teacher_df = read_df[
    [#'Teacher Years Experience',
     'Teacher Birth Year',
     #'Certified Teacher',
     'Teacher Gender',
     'Teacher Highest Degree',
     'Teacher License Type'
    #  'Type of Teacher Certification',
    #  'Year of Teacher Certification'
]].drop_duplicates().reset_index(drop = True)

# %%
teacher_df
# Out:
#      Teacher Birth Year Teacher Gender Teacher Highest Degree  \
# 0                1966.0         Female              Doctorate
# 1                1981.0           Male             Bachelor's
# 2                1979.0           Male               Master's
# 3                1982.0           Male               Master's
# 4                1980.0         Female             Bachelor's
# ..                  ...            ...                    ...
# 98               1993.0         Female             Bachelor's
# 99               1970.0         Female             Bachelor's
# 100              1978.0         Female             Bachelor's
# 101              1971.0         Female           Master's +30
# 102              1996.0           Male               Master's
#
#           Teacher License Type
# 0    Postgraduate Professional
# 1      Collegiate Professional
# 2    Postgraduate Professional
# 3    Postgraduate Professional
# 4      Collegiate Professional
# ..                         ...
# 98     Collegiate Professional
# 99     Collegiate Professional
# 100    Collegiate Professional
# 101  Postgraduate Professional
# 102    Collegiate Professional
#
# [103 rows x 4 columns]

# %% [markdown]
# ## Breakdown of certified teachers

# %%
cert_count_read = teacher_df['Certified Teacher'].value_counts()
cert_count_read = cert_count_read.to_list()
print(f"certified teachers for reading: N - {cert_count_read[0]}, Y - {cert_count_read[1]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Certified Teacher'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-1834c9d816b2> in <cell line: 1>()
# ----> 1 cert_count_read = teacher_df['Certified Teacher'].value_counts()
#       2 cert_count_read = cert_count_read.to_list()
#       3 print(f"certified teachers for reading: N - {cert_count_read[0]}, Y - {cert_count_read[1]}")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Certified Teacher'

# %%
xlab = ['N', 'Y']
x = np.arange(len(xlab))
width = 0.4

plt.bar(x + 0.2, cert_count_read, width);
plt.title("Count of Certified Teachers");
plt.xticks(x, xlab);
plt.legend(["Reading"]);

# %% [markdown]
# There are many more teachers that aren't certified than certified ones for both math and reading. We should take this into consideration when analyzing the data.

# %% [markdown]
# ## Breakdown of type of certification

# %%
type_cert_count_math = math_df['Type of Certification'].value_counts() # does not count NA
type_cert_count_math = type_cert_count_math.to_list()
# type_cert_count_math.append(len(math_df['Type of Certification']) - np.sum(type_cert_count_math))
print(f"certified teachers for math: NO - {type_cert_count_math[0]}, FULL - {type_cert_count_math[1]}, MICRO - {type_cert_count_math[2]}")

type_cert_count_read = read_df['Type of Certification'].value_counts() # does not count NA
type_cert_count_read = type_cert_count_read.to_list()
# type_cert_count_read.append(len(read_df['Certified Teacher']) - np.sum(type_cert_count_read))
type_cert_count_read[:] = [type_cert_count_read[i] for i in [0, 2, 1]]
print(f"certified teachers for reading: NO - {type_cert_count_read[0]}, FULL - {type_cert_count_read[1]}, MICRO - {type_cert_count_read[2]}")
# Out:
# certified teachers for math: NO - 2542, FULL - 163, MICRO - 147
# certified teachers for reading: NO - 2261, FULL - 278, MICRO - 283

# %%
xlab = ['NO', 'FULL', 'MICRO']
x = np.arange(len(xlab))
width = 0.4

plt.bar(x - 0.2, type_cert_count_math, width);
plt.bar(x + 0.2, type_cert_count_read, width);
plt.title("Count of Certified Teachers by Type");
plt.xticks(x, xlab);
plt.legend(["Math", "Reading"]);

# %% [markdown]
# The amount of FULL and MICRO certified teachers are the same, and are heavily outweighed by the number of teachers that are not certified.

# %% [markdown]
# # Compare growth of student between certified and non-certified teachers

# %%
math_df_growth = math_df[["Type of Certification", "Growth"]].dropna()
math_df_growth.head(n=5)
# Out:
#   Type of Certification     Growth
# 0                    NO  -1.334740
# 3                    NO   3.149417
# 4                    NO  85.981716
# 5                    NO  -6.658970
# 6                    NO -34.526420

# %%
math_df_growth.boxplot(by="Type of Certification");
plt.title("Teacher's Type of Certification with Student's Growth for Math");
# Out:
# Text(0.5, 1.0, "Teacher's Type of Certification with Student's Growth for Math")

# %%
read_df_growth = read_df[["Type of Certification", "Growth"]].dropna()
read_df_growth.head(n=5)
# Out:
#   Type of Certification      Growth
# 0                    NO   68.868100
# 1                    NO  104.475810
# 2                    NO   25.459206
# 3                    NO  -10.995747
# 4                    NO   45.422226

# %%
read_df_growth.boxplot(by="Type of Certification");
plt.title("Teacher's Type of Certification with Student's Growth for Reading");

# %% [markdown]
# The boxplots for teacher's certification and the student's growth (which is defined by expected and actual) is not that different between certified and non certified teachers.
